# %%
from flask import Flask, request, jsonify
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pickle
# Out:
# WARNING:tensorflow:From c:\Users\Prasanna\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
app = Flask(__name__)

# %%
model = tf.keras.models.load_model('saved_model/trademark_model.h5')

# %%
# Load the preprocessor and label encoder
with open('saved_model/preprocessor.pkl', 'rb') as f:
    ps, label_encoder, voc_size, sent_length = pickle.load(f)

# %%
# Define the route for the API
@app.route('/predict', methods=['POST'])
def predict():
    data = request.get_json(force=True)
    description = data.get('description', None)
    if description is None:
        return jsonify({'error': 'No description provided'}), 400

    # Predict the class
    predicted_class = predict_class(description, model, ps, label_encoder, voc_size, sent_length)

    return jsonify({'description': description, 'predicted_class': predicted_class})

# %%
# Run the app
if __name__ == '__main__':
    app.run(debug=True)
